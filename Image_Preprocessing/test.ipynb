# %%
import pickle

# %%
path = '/Users/wizard/Memory-Net-Inverse/Results/Loss_Function/Memory_Residual-.75'

proj = 5
sampling = 10 

curr_path = f"{path}/{proj} Projections/{sampling}% Sampling/history.pkl"

# %%
with open(curr_path, 'rb') as f:
    print(pickle.load(f))
# Out:
# {'train_losses': [0.10070351010560989, 0.03815794432659944, 0.0339004208346208, 0.03166059834427304, 0.030204956549737188, 0.028629399710231356, 0.027697207305166456, 0.026892237961292267, 0.02638702644407749, 0.025820666874448457, 0.02539249070154296, 0.024887545673383606, 0.024355998527672555, 0.02404086213144991, 0.02371921045747068, 0.023427930156389873, 0.023202803625000847, 0.02281898219883442, 0.022553543370631007, 0.022359072243173916, 0.02210221967763371, 0.021941502021418677, 0.021776634830567573, 0.021581325580676398, 0.02140798884464635, 0.02131663912369145, 0.021113116507728895, 0.020921941566798424, 0.02085269296500418, 0.020838623396224446, 0.02059049008952247, 0.020475230026576256, 0.020404758556021585, 0.020311200282639927, 0.020172900231348143, 0.020107545162240663, 0.020035328004095288, 0.019962458693318898, 0.019819213307566114, 0.019757658989893064, 0.019777482920222814, 0.01962774973611037, 0.019617461941308447, 0.019461530789732933, 0.01941657521161768, 0.01937
# ...
